# %%
from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
import os
path = '/content/drive/My Drive/ChineseNER'
os.chdir(path)

# %%
# !pwd
# Out:
# /content/drive/My Drive/ChineseNER

# %%
# !ls -lh
# Out:
# total 90K
# drwx------ 2 root root 4.0K Oct 10 07:30 bert
# -rw------- 1 root root  32K Oct 23 11:40 bert_ner.py
# drwx------ 2 root root 4.0K Oct 10 07:30 bilstm_crf
# drwx------ 2 root root 4.0K Oct 10 07:30 chinese_L-12_H-768_A-12
# drwx------ 2 root root 4.0K Oct 10 07:30 data
# drwx------ 2 root root 4.0K Oct 10 07:30 metrics
# drwx------ 2 root root 4.0K Oct 10 07:30 output
# drwx------ 2 root root 4.0K Oct 10 07:30 POS
# -rw------- 1 root root  31K Oct 25 06:03 run_bert_ner.ipynb

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 1.15.2

# %%
# !python bert_ner.py\
    --do_lower_case=False \
    --do_train=True   \
    --do_eval=True   \
    --do_test=False \
    --dataset=MSRA-pos   \
    --vocab_file=./chinese_L-12_H-768_A-12/vocab_update.txt   \
    --bert_config_file=./chinese_L-12_H-768_A-12/bert_config.json   \
    --init_checkpoint=./chinese_L-12_H-768_A-12/bert_model.ckpt   \
    --max_seq_length=128   \
    --train_batch_size=32   \
    --learning_rate=2e-5   \
    --num_train_epochs=10.0   \
    --dropout_rate=0.5   \
    --output_dir=./output/MSRA-pos/bert_bilstm_crf/   \
    --bilstm=True   \
    --crf=True   \
    --use_pos=True
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:tensorflow:global_step/sec: 0.825506
# I1025 12:24:29.577193 140296470083456 tpu_estimator.py:2307] global_step/sec: 0.825506
# INFO:tensorflow:examples/sec: 26.4162
# I1025 12:24:29.577808 140296470083456 tpu_estimator.py:2308] examples/sec: 26.4162
# INFO:tensorflow:global_step/sec: 0.826471
# I1025 12:24:30.787149 140296470083456 tpu_estimator.py:2307] global_step/sec: 0.826471
# INFO:tensorflow:examples/sec: 26.4471
# I1025 12:24:30.787767 140296470083456 tpu_estimator.py:2308] examples/sec: 26.4471
# INFO:tensorflow:global_step/sec: 0.824442
# I1025 12:24:32.000128 140296470083456 tpu_estimator.py:2307] global_step/sec: 0.824442
# INFO:tensorflow:examples/sec: 26.3821
# I1025 12:24:32.000602 140296470083456 tpu_estimator.py:2308] examples/sec: 26.3821
# INFO:tensorflow:global_step/sec: 0.82952
# I1025 12:24:33.205612 140296470083456 tpu_estimator.py:2307] global_step/sec: 0.82952
# INFO:tensorflow:examples/sec: 26.5446
# ...

# %%
# !python bert_ner.py\
    --do_lower_case=False \
    --do_train=False   \
    --do_eval=True   \
    --do_test=True \
    --dataset=MSRA   \
    --vocab_file=./chinese_L-12_H-768_A-12/vocab_update.txt   \
    --bert_config_file=./chinese_L-12_H-768_A-12/bert_config.json   \
    --init_checkpoint=./output/MSRA/bert_bilstm_crf_pos/model.ckpt-6332   \
    --max_seq_length=128   \
    --train_batch_size=32   \
    --learning_rate=2e-5   \
    --dropout_rate=0.5   \
    --output_dir=./output/MSRA/bert_bilstm_crf_pos/   \
    --bilstm=True   \
    --crf=True   \
    --use_pos=True
